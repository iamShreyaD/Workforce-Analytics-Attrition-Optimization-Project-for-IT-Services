# %%
import pandas as pd
import numpy as np

# %%
#loading csv data base
df = pd.read_csv("employee_ml.csv")

# %%
#verifying the dataframe with first five records
df.head()
# Out:
#    employee_id  year  status business_unit department_name job_title  \
# 0         1318  2006  ACTIVE    HEADOFFICE       Executive       CEO
# 1         1318  2007  ACTIVE    HEADOFFICE       Executive       CEO
# 2         1318  2008  ACTIVE    HEADOFFICE       Executive       CEO
# 3         1318  2009  ACTIVE    HEADOFFICE       Executive       CEO
# 4         1318  2010  ACTIVE    HEADOFFICE       Executive       CEO
#
#    city_name  store_no gender termination_date   hire_date  birth_date  age  \
# 0  Vancouver        35      M              NaN  28-08-1989  03-01-1954   52
# 1  Vancouver        35      M              NaN  28-08-1989  03-01-1954   53
# 2  Vancouver        35      M              NaN  28-08-1989  03-01-1954   54
# 3  Vancouver        35      M              NaN  28-08-1989  03-01-1954   55
# 4  Vancouver        35      M              NaN  28-08-1989  03-01-1954   56
#
#    length_of_service termreason_desc   termtype_desc
# 0                 17  Not Applicable  Not Applicable
# 1                 18  Not Applicable  Not Applicable
# 2                 19  Not Applicable  Not Applicable
# 3                 20  Not Applicable  Not Applicable
# 4                 21  Not Applicable  Not Applicable

# %%
#verifying number of rows and columns
df.shape
# Out:
# (49653, 16)

# %%
#verifying data type
df.dtypes
# Out:
# employee_id           int64
# year                  int64
# status               object
# business_unit        object
# department_name      object
# job_title            object
# city_name            object
# store_no              int64
# gender               object
# termination_date     object
# hire_date            object
# birth_date           object
# age                   int64
# length_of_service     int64
# termreason_desc      object
# termtype_desc        object
# dtype: object

# %%
#counting null records across columns
df.isna().sum()
# Out:
# employee_id              0
# year                     0
# status                   0
# business_unit            0
# department_name          0
# job_title                0
# city_name                0
# store_no                 0
# gender                   0
# termination_date     42450
# hire_date                0
# birth_date               0
# age                      0
# length_of_service        0
# termreason_desc          0
# termtype_desc            0
# dtype: int64

# %%
#dropping unrequired columns
df = df.drop(['termination_date', 'termreason_desc', 'termtype_desc'], axis=1)

# %%
#verifying the columns
df.columns
# Out:
# Index(['employee_id', 'year', 'status', 'business_unit', 'department_name',
#        'job_title', 'city_name', 'store_no', 'gender', 'hire_date',
#        'birth_date', 'age', 'length_of_service'],
#       dtype='object')

# %%
#creating column 'attrition_flag'
df['attrition_flag'] = df['status'].apply(lambda x: 1 if x == 'TERMINATED' else 0)

# %%
#verifying the first five records
df.head()
# Out:
#    employee_id  year  status business_unit department_name job_title  \
# 0         1318  2006  ACTIVE    HEADOFFICE       Executive       CEO
# 1         1318  2007  ACTIVE    HEADOFFICE       Executive       CEO
# 2         1318  2008  ACTIVE    HEADOFFICE       Executive       CEO
# 3         1318  2009  ACTIVE    HEADOFFICE       Executive       CEO
# 4         1318  2010  ACTIVE    HEADOFFICE       Executive       CEO
#
#    city_name  store_no gender   hire_date  birth_date  age  length_of_service  \
# 0  Vancouver        35      M  28-08-1989  03-01-1954   52                 17
# 1  Vancouver        35      M  28-08-1989  03-01-1954   53                 18
# 2  Vancouver        35      M  28-08-1989  03-01-1954   54                 19
# 3  Vancouver        35      M  28-08-1989  03-01-1954   55                 20
# 4  Vancouver        35      M  28-08-1989  03-01-1954   56                 21
#
#    attrition_flag
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
#creating lists: numeric_features, categorical_features, target
numeric_features = ["year", "store_no", "age", "length_of_service"]
categorical_features = ["department_name", "business_unit", "job_title", "gender", "city_name"]
target = "attrition_flag"

# %%
#creating dataframe for machine learning
model_df = df[numeric_features + categorical_features + [target]].copy()

# %%
#verifying dataframe with first five records
model_df.head()
# Out:
#    year  store_no  age  length_of_service department_name business_unit  \
# 0  2006        35   52                 17       Executive    HEADOFFICE
# 1  2007        35   53                 18       Executive    HEADOFFICE
# 2  2008        35   54                 19       Executive    HEADOFFICE
# 3  2009        35   55                 20       Executive    HEADOFFICE
# 4  2010        35   56                 21       Executive    HEADOFFICE
#
#   job_title gender  city_name  attrition_flag
# 0       CEO      M  Vancouver               0
# 1       CEO      M  Vancouver               0
# 2       CEO      M  Vancouver               0
# 3       CEO      M  Vancouver               0
# 4       CEO      M  Vancouver               0

# %%
#verifying number of columns and rows
model_df.shape
# Out:
# (49653, 10)

# %%
#counting records from attrition_flag
model_df['attrition_flag'].value_counts()
# Out:
# attrition_flag
# 0    48168
# 1     1485
# Name: count, dtype: int64

# %%
#calculating percentage split of attrition_flag
model_df['attrition_flag'].value_counts(normalize=True) * 100
# Out:
# attrition_flag
# 0    97.009244
# 1     2.990756
# Name: proportion, dtype: float64

# %%
#summary of attrition
imbalance_summary = (model_df['attrition_flag'].value_counts().to_frame(name="count"))
imbalance_summary["percentage"] = (model_df["attrition_flag"].value_counts(normalize=True) * 100)
imbalance_summary
# Out:
#                 count  percentage
# attrition_flag
# 0               48168   97.009244
# 1                1485    2.990756

# %%
#job title frequency
job_freq = df['job_title'].value_counts(normalize=True) 
job_freq
# Out:
# job_title
# Meat Cutter                        0.201075
# Dairy Person                       0.173001
# Produce Clerk                      0.165891
# Baker                              0.163052
# Cashier                            0.137273
# Shelf Stocker                      0.113226
# Customer Service Manager           0.006163
# Processed Foods Manager            0.005820
# Meats Manager                      0.005740
# Bakery Manager                     0.005740
# Produce Manager                    0.005599
# Store Manager                      0.005458
# Recruiter                          0.001249
# HRIS Analyst                       0.001108
# Accounting Clerk                   0.001007
# Benefits Admin                     0.000705
# Accounts Receiveable Clerk         0.000604
# Labor Relations Analyst            0.000604
# Trainer                            0.000524
# Accounts Payable Clerk             0.000503
# Investment Analyst                 0.000403
# Auditor                            0.000403
# Systems Analyst                    0.000403
# Compensation Analyst               0.000403
# Corporate Lawyer                   0.000342
# Legal Counsel                      0.000201
# VP Human Resources                 0.000201
# CEO                                0.000201
# VP Stores                          0.000201
# VP Finance                         0.000201
# Exec Assistant, Legal Counsel      0.000201
# Exec Assistant, Human Resources    0.000201
# CHief Information Officer          0.000201
# Director, Recruitment              0.000201
# Exec Assistant, Finance            0.000201
# Exec Assistant, VP Stores          0.000201
# Director, Employee Records         0.000181
# Director, HR Technology            0.000181
# Director, Accounting               0.000181
# Dairy Manager                      0.000181
# Director, Accounts Payable         0.000181
# Director, Accounts Receivable      0.000181
# Director, Training                 0.000081
# Director, Labor Relations          0.000081
# Director, Audit                    0.000081
# Director, Compensation             0.000081
# Director, Investments              0.000081
# Name: proportion, dtype: float64

# %%
#titles that are rare in dataframe
rare_titles = job_freq[job_freq < 0.01].index
rare_titles
# Out:
# Index(['Customer Service Manager', 'Processed Foods Manager', 'Meats Manager',
#        'Bakery Manager', 'Produce Manager', 'Store Manager', 'Recruiter',
#        'HRIS Analyst', 'Accounting Clerk', 'Benefits Admin',
#        'Accounts Receiveable Clerk', 'Labor Relations Analyst', 'Trainer',
#        'Accounts Payable Clerk', 'Investment Analyst', 'Auditor',
#        'Systems Analyst', 'Compensation Analyst', 'Corporate Lawyer',
#        'Legal Counsel', 'VP Human Resources', 'CEO', 'VP Stores', 'VP Finance',
#        'Exec Assistant, Legal Counsel', 'Exec Assistant, Human Resources',
#        'CHief Information Officer', 'Director, Recruitment',
#        'Exec Assistant, Finance', 'Exec Assistant, VP Stores',
#        'Director, Employee Records', 'Director, HR Technology',
#        'Director, Accounting', 'Dairy Manager', 'Director, Accounts Payable',
#        'Director, Accounts Receivable', 'Director, Training',
#        'Director, Labor Relations', 'Director, Audit',
#        'Director, Compensation', 'Director, Investments'],
#       dtype='object', name='job_title')

# %%
#replacing job titles that are rare with 'Other'
df['job_title'] = df['job_title'].replace(rare_titles, 'Other')

# %%
#verifying the changes made in 'job_title'
df['job_title'].value_counts()
# Out:
# job_title
# Meat Cutter      9984
# Dairy Person     8590
# Produce Clerk    8237
# Baker            8096
# Cashier          6816
# Shelf Stocker    5622
# Other            2308
# Name: count, dtype: int64

# %%
df_encoded = pd.get_dummies(df, columns=categorical_features, drop_first=True)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\shrey\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\shrey\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\shrey\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\shrey\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\shrey\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\shrey\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#importing
from sklearn.model_selection import train_test_split

# %%
#target
y = df['attrition_flag']

# %%
#drop non-features
X = df.drop(columns=[
    'attrition_flag', 'employee_id', 'status', 'hire_date', 'birth_date'
])

# %%
#importing for encode categoricals and scale numerics
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
#verifying categorical features
categorical_features
# Out:
# ['department_name', 'business_unit', 'job_title', 'gender', 'city_name']

# %%
#verifying numeric features
numeric_features
# Out:
# ['year', 'store_no', 'age', 'length_of_service']

# %%
#preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
    ]
)

# %%
#train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
#importing for logical regression
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
#logistic regression
log_reg = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(
        max_iter=1000,
        class_weight='balanced',
        random_state=42
    ))
])

# %%
#training
log_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['year', 'store_no', 'age',
#                                                    'length_of_service']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['department_name',
#                                                    'business_unit', 'job_title',
#                                                    'gender', 'city_name'])])),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
#importing from random forest
from sklearn.ensemble import RandomForestClassifier

# %%
#random forest
rf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(
        n_estimators=200,
        max_depth=None,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1
    ))
])

# %%
#training
rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['year', 'store_no', 'age',
#                                                    'length_of_service']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['department_name',
#                                                    'business_unit', 'job_title',
#                                                    'gender', 'city_name'])])),
#                 ('model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=200, n_jobs=-1,
#                                         random_state=42))])

# %%
#importing for evaluation
from sklearn.metrics import(
    roc_auc_score, classification_report, confusion_matrix
)

# %%
# helper function
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]

    print("ROC-AUC", roc_auc_score(y_test, y_proba))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
#evaluating logistic regression
print("LOGISTIC REGRESSION RESULTS")
evaluate_model(log_reg, X_test, y_test)
# Out:
# LOGISTIC REGRESSION RESULTS
# ROC-AUC 0.8828341893338713
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92     14450
#            1       0.15      0.78      0.25       446
#
#     accuracy                           0.86     14896
#    macro avg       0.57      0.82      0.59     14896
# weighted avg       0.97      0.86      0.90     14896
#
# Confusion Matrix:
#  [[12485  1965]
#  [  100   346]]

# %%
#evaluating random forest
print("RANDOM FOREST RESULTS")
evaluate_model(rf, X_test, y_test)
# Out:
# RANDOM FOREST RESULTS
# ROC-AUC 0.936620634009341
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     14450
#            1       0.66      0.73      0.69       446
#
#     accuracy                           0.98     14896
#    macro avg       0.83      0.86      0.84     14896
# weighted avg       0.98      0.98      0.98     14896
#
# Confusion Matrix:
#  [[14285   165]
#  [  121   325]]

# %%
#getting feature names after preprocessing
ohe_features = log_reg.named_steps['preprocessor'].transformers_[1][1]\
    .get_feature_names_out(categorical_features)

# %%
#combining with numeric features
all_features = np.concatenate([numeric_features, ohe_features])
len(all_features)
# Out:
# 76

# %%
#creating dataframe and extracting coefficients
logreg_coef = pd.DataFrame({
    "feature": all_features,
    "coefficient": log_reg.named_steps['model'].coef_[0]
})

logreg_coef["abs_coef"] = logreg_coef["coefficient"].abs()

#top positive i.e. increase attrition
top_risk = logreg_coef.sort_values("coefficient", ascending=False).head(10)

#top negative i.e. reduce attrition
top_protective = logreg_coef.sort_values("coefficient").head(10)

print("Top 10 features increasing attrition:")
print(top_risk)
print("\nTop 10 features reducing attrition:")
print(top_protective)
# Out:
# Top 10 features increasing attrition:
#                        feature  coefficient  abs_coef
# 2                          age     3.309220  3.309220
# 69         city_name_Valemount     2.516584  2.516584
# 74        city_name_White Rock     2.175520  2.175520
# 55  city_name_New Westminister     1.876254  1.876254
# 31             job_title_Other     1.872980  1.872980
# 58       city_name_Ocean Falls     1.696309  1.696309
# 62         city_name_Princeton     1.555802  1.555802
# 72          city_name_Victoria     1.439963  1.439963
# 48       city_name_Grand Forks     1.251404  1.251404
# 0                         year     1.232209  1.232209
#
# Top 10 features reducing attrition:
#                        feature  coefficient  abs_coef
# 3            length_of_service    -3.438432  3.438432
# 37        city_name_Aldergrove    -2.886883  2.886883
# 40           city_name_Burnaby    -2.464752  2.464752
# 36        city_name_Abbotsford    -1.985151  1.985151
# 16  department_name_Investment    -1.758043  1.758043
# 43         city_name_Cranbrook    -1.692242  1.692242
# 41        city_name_Chilliwack    -1.688569  1.688569
# 13   department_name_Executive    -1.658111  1.658111
# 52           city_name_Langley    -1.498636  1.498636
# 54            city_name_Nelson    -1.423878  1.423878

# %%
#random forest feature importance
rf_importances = rf.named_steps['model'].feature_importances_
rf_importances_df = pd.DataFrame({
    "feature": all_features,
    "importance": rf_importances
})

rf_importances_sorted = rf_importances_df.sort_values("importance", ascending=False)

print("\nTop 10 Random Forest features by importance:")
print(rf_importances_sorted.head(10))
# Out:
# Top 10 Random Forest features by importance:
#                              feature  importance
# 2                                age    0.359202
# 3                  length_of_service    0.160123
# 0                               year    0.112919
# 1                           store_no    0.084445
# 35                          gender_M    0.020447
# 34                          gender_F    0.020334
# 46             city_name_Fort Nelson    0.012828
# 10  department_name_Customer Service    0.012483
# 55        city_name_New Westminister    0.011883
# 70               city_name_Vancouver    0.011011

# %%
#predicting attrition probability using random forest
attrition_prob = rf.predict_proba(X)[:, 1]

# %%
attrition_prob.min(), attrition_prob.max()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %%
#creating risk bands
risk_band = np.where(
    attrition_prob > 0.7, "High",
    np.where(attrition_prob >= 0.4, "Medium", "Low")
)

# %%
#building final scored dataset
scored_df = df.copy()

scored_df["attrition_probability"] = attrition_prob
scored_df["risk_band"] = risk_band

#rounding off
scored_df["attrition_probability"] = scored_df["attrition_probability"].round(3)

# %%
#risk band distribution
scored_df["risk_band"].value_counts(normalize=True)
# Out:
# risk_band
# Low       0.960385
# High      0.024067
# Medium    0.015548
# Name: proportion, dtype: float64

# %%
#top high-risk employees
scored_df.sort_values("attrition_probability", ascending=False).head(10)
# Out:
#        employee_id  year      status business_unit department_name  \
# 48754         3830  2010  TERMINATED        STORES         Produce
# 48898         4366  2006  TERMINATED        STORES           Meats
# 48432         2360  2006  TERMINATED        STORES           Meats
# 48562         2946  2007  TERMINATED        STORES           Meats
# 49073         4811  2013  TERMINATED        STORES           Meats
# 49072         4809  2008  TERMINATED        STORES         Produce
# 49071         4808  2008  TERMINATED        STORES         Produce
# 49070         4807  2008  TERMINATED        STORES           Meats
# 48896         4357  2006  TERMINATED        STORES           Meats
# 48435         2386  2006  TERMINATED        STORES           Meats
#
#            job_title        city_name  store_no gender   hire_date  \
# 48754  Produce Clerk         Victoria        37      F  28-09-1996
# 48898    Meat Cutter        Vancouver        35      M  22-04-1998
# 48432    Meat Cutter          Nanaimo        18      F  01-10-1992
# 48562    Meat Cutter         Victoria        37      F  08-05-1994
# 49073    Meat Cutter        Vancouver        35      F  19-08-1999
# 49072  Produce Clerk         Victoria        37      M  18-08-1999
# 49071  Produce Clerk  New Westminster        21      M  17-08-1999
# 49070    Meat Cutter        Vancouver        35      M  15-08-1999
# 48896    Meat Cutter        Vancouver        35      M  14-04-1998
# 48435    Meat Cutter  New Westminster        21      F  25-10-1992
#
#        birth_date  age  length_of_service  attrition_flag  \
# 48754  23-03-1945   65                 13               1
# 48898  15-10-1946   60                  8               1
# 48432  26-03-1941   65                 13               1
# 48562  31-10-1942   65                 13               1
# 49073  11-02-1948   65                 13               1
# 49072  10-02-1948   60                  8               1
# 49071  09-02-1948   60                  8               1
# 49070  07-02-1948   60                  8               1
# 48896  07-10-1946   60                  8               1
# 48435  19-04-1941   65                 13               1
#
#        attrition_probability risk_band
# 48754                    1.0      High
# 48898                    1.0      High
# 48432                    1.0      High
# 48562                    1.0      High
# 49073                    1.0      High
# 49072                    1.0      High
# 49071                    1.0      High
# 49070                    1.0      High
# 48896                    1.0      High
# 48435                    1.0      High

# %%
scored_df.to_csv("employee_attrition_scored.csv", index=False)

# %%
#inspecting top 10 Random Forest feature importances
top10_rf_importance = rf_importances_sorted.head(10)
top10_rf_importance
# Out:
#                              feature  importance
# 2                                age    0.359202
# 3                  length_of_service    0.160123
# 0                               year    0.112919
# 1                           store_no    0.084445
# 35                          gender_M    0.020447
# 34                          gender_F    0.020334
# 46             city_name_Fort Nelson    0.012828
# 10  department_name_Customer Service    0.012483
# 55        city_name_New Westminister    0.011883
# 70               city_name_Vancouver    0.011011

# %%
#checking importance sum
rf_importances_sorted["importance"].sum()
# Out:
# np.float64(0.9999999999999999)

# %%
#rounding for dashboard readability
top10_rf_importance["importance"] = top10_rf_importance["importance"].round(4)
top10_rf_importance
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_29012\2620126763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10_rf_importance["importance"] = top10_rf_importance["importance"].round(4)
#                              feature  importance
# 2                                age      0.3592
# 3                  length_of_service      0.1601
# 0                               year      0.1129
# 1                           store_no      0.0844
# 35                          gender_M      0.0204
# 34                          gender_F      0.0203
# 46             city_name_Fort Nelson      0.0128
# 10  department_name_Customer Service      0.0125
# 55        city_name_New Westminister      0.0119
# 70               city_name_Vancouver      0.0110

# %%
#exporting attrition_feature_importance.csv
top10_rf_importance.to_csv(
    "attrition_feature_importance.csv",
    index=False
)
print("attrition_feature_importance.csv exported successfully")
# Out:
# attrition_feature_importance.csv exported successfully
